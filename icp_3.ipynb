# %% [markdown]
# <a href="https://colab.research.google.com/github/vezr96/Class-Programming-1-Vance/blob/main/icp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
import numpy as np
import pandas as pd


data = {
    'ID' : np.arange(1, 1000001),
    'Value' : np.random.rand(1000000),
    'Category': np.random.choice(['A', 'B', 'C', 'D'], size=1000000)
}

ot = pd.DataFrame(data)
ot.head(10)
ot['Value']

ot.rename(columns={
    'ID': 'ID Number',
    'Value': 'Random Value',
    'Category': 'Choices'
}, inplace=True)
ot.head()
# Out:
# ...
#    ID Number  Random Value Choices
# 0          1      0.021116       C
# 1          2      0.203014       C
# 2          3      0.542679       A
# 3          4      0.624794       D
# 4          5      0.829251       B

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
print("Original DataFrame:")
print(student_data)
print('\nSplit the said data on school_code school_code, class wise:')
result = student_data.groupby(['school_code', 'class'])
for name,group in result:
    print("\nGroup:")
    print(name)
    print(group)
# Out:
# Original DataFrame:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4
#
# Split the said data on school_code school_code, class wise:
#
# Group:
# ('s001', 'V')
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
#
#     address
# S1  street1
#
# Group:
# ('s001', 'VI')
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/data.csv"

# %%
import pandas as pd
df = pd.read_csv(path)
df.describe

# %% [markdown]
# These commands imports the csv file into the pandas dataframe then describes the file.

# %%
df.isnull().sum()
df.fillna(df.mean(), inplace=True)

# %% [markdown]
# These two commands check the documents if there are null values and the second fills those null values with mean values.

# %%
subset = df[['Duration','Pulse']]
subset.agg(['mean', 'max', 'min', 'count'])
# Out:
#          Duration       Pulse
# mean    63.846154  107.461538
# max    300.000000  159.000000
# min     15.000000   80.000000
# count  169.000000  169.000000

# %% [markdown]
# These commands selects the two columns duration and pulse and then aggregates the data using min,max,count,and mean.

# %%
df[(df['Calories'] >= 500) & (df['Calories'] <= 1000)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# This shows a filter of calories that are only from 500 to 1000.

# %%
df[(df['Calories'] > 500) & (df['Pulse'] < 100)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# This shows a filter that only showsthe calories that are greater than 500 and pulse that is less than 100.

# %%
df_modified = df.drop('Maxpulse', axis=1)

# %% [markdown]
# This command creates a new columnwith the data from Maxpulse.

# %%
df.drop('Maxpulse', axis=1, inplace=True)

# %% [markdown]
# This command drops Maxpulse from the main df dataframe.

# %%
df['Calories'] = df['Calories'].astype(int)

# %% [markdown]
# This command converts the dtatype of calories to int

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Duration'], df['Calories'])
plt.show()

# %% [markdown]
# This command creates a scatter plot based on Duration and Calories then shows it
